# %% [markdown]
# # Exploratory data analysis
#
# The purpose of this file is to study relationships between predictors, find correlation, and visualize the behaviour of the response variable.

# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv("npf_train.csv")
train_data = train_data.drop(["id", "partlybad"], axis = 1)
class2 = np.array(["nonevent", "event"])
train_data.insert(1, "class2", class2[(train_data["class4"] != "nonevent").astype(int)])
train_data.head()
# Out:
#          date    class2    class4  CO2168.mean  CO2168.std  CO2336.mean  \
# 0  2000-01-17     event        Ib   368.771711    0.310309   368.665658
# 1  2000-02-28  nonevent  nonevent   378.197295    1.001493   378.083089
# 2  2000-03-24     event        Ib   373.043158    0.749865   372.930066
# 3  2000-03-30     event        II   375.643019    0.558629   375.549430
# 4  2000-04-04  nonevent  nonevent   377.661030    0.408421   377.609576
#
#    CO2336.std  CO242.mean  CO242.std  CO2504.mean  ...  T672.mean  T672.std  \
# 0    0.305127  369.371184   0.333606   368.616053  ...  -1.476016  0.250952
# 1    1.025472  378.671311   1.017208   378.029508  ...   1.479493  0.313460
# 2    0.728411  373.569735   0.835240   372.869868  ...  -0.270844  2.037111
# 3    0.540964  376.045849   0.580730   375.506013  ...   5.622308  2.509758
# 4    0.423963  378.117134   0.417243   377.582242  ...   1.140121  1.438071
#
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464 entries, 0 to 463
# Columns: 103 entries, date to CS.std
# dtypes: float64(100), object(3)
# memory usage: 373.5+ KB

# %%
train_data.describe()
# Out:
#        CO2168.mean  CO2168.std  CO2336.mean  CO2336.std  CO242.mean  \
# count   464.000000  464.000000   464.000000  464.000000  464.000000
# mean    382.072525    3.129971   382.086831    2.940651  382.977945
# std      11.080110    3.222030    11.055166    2.973224   10.665746
# min     359.579024    0.053968   359.096905    0.048990  361.904203
# 25%     374.398155    0.845635   374.389589    0.789586  375.410833
# 50%     380.814198    1.952732   380.727947    1.899320  381.600970
# 75%     389.048782    4.428063   389.028476    4.141001  389.731608
# max     421.511176   19.460521   421.057843   17.439857  422.627800
#
#         CO242.std  CO2504.mean  CO2504.std   Glob.mean    Glob.std  ...  \
# count  464.000000   464.000000  464.000000  464.000000  464.000000  ...
# mean     3.991636   381.990305    2.718960  188.904482  138.932525  ...
# std      4.184408    11.067589    2.696396  126.716262   93.308852  ...
# ...

# %%
#Check for NaN columns
train_data.isna().any()
# Out:
# date           False
# class2         False
# class4         False
# CO2168.mean    False
# CO2168.std     False
#                ...
# UV_A.std       False
# UV_B.mean      False
# UV_B.std       False
# CS.mean        False
# CS.std         False
# Length: 103, dtype: bool

# %%
train_data.isna().any().sum()
# Out:
# 0

# %%
train_data.dtypes
# Out:
# date            object
# class2          object
# class4          object
# CO2168.mean    float64
# CO2168.std     float64
#                 ...
# UV_A.std       float64
# UV_B.mean      float64
# UV_B.std       float64
# CS.mean        float64
# CS.std         float64
# Length: 103, dtype: object

# %% [markdown]
# Leave-one-station-out cross-validation would fit into our data quite well, as we can logically group the training data based on the year of season. It would be desirable to transform the date into usable data that can be fed to a classification model.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(train_data, hue = "class4", vars = train_data.columns[3:8], kind = 'reg')
plt.show()

# %%
sns.heatmap(train_data.filter(like = '.mean', axis = 1).corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# As we can from the heatmap, the measurements of the same feature at different heights are correlated.

# %%
sns.boxplot(data=train_data.filter(regex='CO2.*.mean', axis = 1)).set_title('Boxplot of CO2 in various heights')
# Out:
# Text(0.5, 1.0, 'Boxplot of CO2 in various heights')

# %% [markdown]
# There are possible outliers in the measurements of CO2.

# %%
sns.boxplot(data=train_data.filter(regex='H2O.*.mean', axis = 1)).set_title('Boxplot of H2O in various heights')
# Out:
# Text(0.5, 1.0, 'Boxplot of H2O in various heights')

# %% [markdown]
# There are possible outliers in the measurements of H2O.

# %%
sns.boxplot(data=train_data.filter(regex='NO.*.mean', axis = 1)).set_title('Boxplot of NO in various heights')
# Out:
# Text(0.5, 1.0, 'Boxplot of NO in various heights')

# %% [markdown]
# There are possible outliers in the measurements of NO.

# %%
sns.boxplot(data=train_data.filter(regex='RHIRGA.*.mean', axis = 1)).set_title('Boxplot of RHIRGA in various heights')
# Out:
# Text(0.5, 1.0, 'Boxplot of RHIRGA in various heights')

# %% [markdown]
# There is no outlier in the measurements of RHIRGA.

# %%
sns.boxplot(data=train_data.filter(regex='^T.*.mean', axis = 1)).set_title('Boxplot of T in various heights')
# Out:
# Text(0.5, 1.0, 'Boxplot of T in various heights')

# %% [markdown]
# There are possible outliers in the measurements of Temperature.

# %%
sns.boxplot(data=train_data.filter(regex='UV.*.mean', axis = 1)).set_title('Boxplot of UV in various heights')
# Out:
# Text(0.5, 1.0, 'Boxplot of UV in various heights')

# %% [markdown]
# There is no outlier in the measurement of UV.

# %%
sns.boxplot(data=train_data.filter(regex='CS.*.mean', axis = 1)).set_title('Boxplot of CS in various heights')
# Out:
# Text(0.5, 1.0, 'Boxplot of CS in various heights')

# %% [markdown]
# There are possible ouliers in the measurements of CS.
